# %% [markdown]
# # Representación de las clases del juego Blackjack
# ![blackjack](https://media.istockphoto.com/photos/gambling-hand-holding-poker-cards-and-money-coins-chips-picture-id903362472?k=20&m=903362472&s=612x612&w=0&h=Tyrp0i-VmL0BZ6_rfNAlnd78BtsLQKG05F2xVJNM3Cs=)

# %%
class Baraja:
    #ATRIBUTOS
    tamaño: int
    tipo: str
    #RELACIONES
    cartas: list #Porque son muchas
    juego: Juego
    #MÉTODOS
    def mezclar(): pass

class Carta:
    #ATRIBUTOS
    valor:int
    palo: str
    esta_oculta: bool
    #RELACIONES
    baraja: Baraja
    #MÉTODOS
    def enseñar(): pass

class Mano:
    #ATRIBUTOS
    puntaje: int
    tamaño: int
    #RELACIONES
    cartas: list
    dealer: Dealer
    jugador: Jugador
    #MÉTODOS
    def mostrar_Carta(): pass

class Jugador:
    #ATRIBUTOS
    nombre: str
    detalles: str
    turno: int
    #RELACIONES
    mano: Mano
    fichas: list
    juego: Juego
    #MÉTODOS
    def pedir_Carta(): pass
    def pasar(): pass
    def mostrar_Carta(): pass
    def apostar(): pass

class Fichas:
    #ATRIBUTOS
    valor: int
    tamaño: int
    color: str
    #RELACIONES
    jugador: Jugador
    #MÉTODOS

class Dealer:
    #ATRIBUTOS
    #RELACIONES
    mano: Mano
    juego: Juego
    #MÉTODOS
    def pedir_Carta(): pass
    def pasar(): pass

class Juego:
    #ATRIBUTOS
    menu: list
    cantidad_de_jugadores: int
    Apuesta_ minima_max: int
    tipo_de_dealer: bool
    #RELACIONES
    baraja: Baraja
    dealer: Dealer
    jugador: Jugador
    #MÉTODOS
    def iniciar_Juego(): pass
    def pausar_Juego(): pass
    def quitar_Juego(): pass

# %% [markdown]
# ## Tarea:
# Terminar el diagrama de clases de blackjack
